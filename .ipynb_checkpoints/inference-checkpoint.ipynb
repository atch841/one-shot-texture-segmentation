# %%
import tensorflow as tf
from data_loader import Data_loader
from model import get_model
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /home/viplab/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
texture, ref, label, decode_mask = get_model(is_training=False)
# Out:
# vgg: (?, 256, 256, 64) (?, 128, 128, 128) (?, 64, 64, 256) (?, 32, 32, 512) (?, 16, 16, 512)
# vgg_ref: (?, 64, 64, 64) (?, 32, 32, 128) (?, 16, 16, 256) (?, 8, 8, 512) (?, 4, 4, 512)
# encoding
# (?, 32, 32, 1024)
# (?, 64, 64, 768)
# (?, 128, 128, 384)
# (?, 256, 256, 192)
# encode_texture: (?, 256, 256, 64)
# (?, 8, 8, 1024)
# (?, 16, 16, 768)
# (?, 32, 32, 384)
# (?, 64, 64, 192)
# encode_ref: (?, 64, 64, 64)
# cor: (?, 256, 256, 64)
# decoding
# (?, 16, 16, 192)
# (?, 32, 32, 192)
# (?, 64, 64, 192)
# (?, 128, 128, 192)
# (?, 256, 256, 192)
# decode_out: (?, 256, 256, 1)

# %%
dl_val = Data_loader('val_texture.npy', 8)

# %%
test_data = dl_val.get_batch_data()
saver = tf.train.Saver()
init = tf.global_variables_initializer()
with tf.Session() as sess:
    saver.restore(sess, '/fast_data/one_shot_texture_models/best_model0.46454')
    res1 = sess.run(decode_mask, feed_dict={texture: test_data[0], ref: test_data[2], label: test_data[1]})
# Out:
# INFO:tensorflow:Restoring parameters from /fast_data/one_shot_texture_models/old/best_model0.46454

# %%
b = 0
plt.imshow(test_data[0][b])
plt.show()
plt.imshow(test_data[2][b])
plt.show()
plt.imshow(np.squeeze(res1[b][:,:,0]))
plt.show()
plt.imshow(test_data[1][b][:,:,0])
plt.show()
